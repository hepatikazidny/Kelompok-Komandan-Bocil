# %%
print ("=========================")
print ("Global Feature Extraction")
print ("=========================")
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
import numpy as np
import mahotas
import cv2
import os
import h5py
import glob

# fixed-sizes for image
# fixed_size = tuple((500, 500))
fixed_size = (250, 250)

# path to training data
train_path = os.path.abspath("cat/train/")

# no.of.trees for Random Forests
num_trees = 100

# bins for histogram
bins = 8

# train_test_split size
test_size = 0.20

# seed for reproducing same results
seed = 9
# Out:
# =========================
# Global Feature Extraction
# =========================

# %%
# feature-descriptor-1: Hu Moments
def fd_hu_moments(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    feature = cv2.HuMoments(cv2.moments(image)).flatten()
    return feature

# %%
# feature-descriptor-2: Haralick Texture
def fd_haralick(image):
    # convert the image to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    # compute the haralick texture feature vector
    haralick = mahotas.features.haralick(gray).mean(axis=0)
    # return the result
    return haralick

# %%
# feature-descriptor-3: Color Histogram
def fd_histogram(image, mask=None):
    # convert the image to HSV color-space
    image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    # compute the color histogram
    hist  = cv2.calcHist([image], [0, 1, 2], None, [bins, bins, bins], [0, 256, 0, 256, 0, 256])
    # normalize the histogram
    cv2.normalize(hist, hist)
    # return the histogram
    return hist.flatten()

# %%
# get the training labels
train_labels = os.listdir(train_path)

# sort the training labels
train_labels.sort()
print(train_labels)

# empty lists to hold feature vectors and labels
global_features = []
labels = []

i, j = 0, 0
k = 0

# num of images per class
images_per_class = 80
# Out:
# ['Abyssinian', 'Bengal', 'Birman', 'Bombay', 'British_Shorthair', 'Maine_Coon', 'Persian', 'Ragdoll', 'Russian_Blue', 'Siamese', 'Sphynx']

# %%
# loop over the training data sub-folders
for training_name in train_labels:
    # join the training data path and each species training folder
    dir = os.path.join(train_path, training_name)

    # get the current training label
    current_label = training_name
    
    print(current_label)
    
    list_images = [f for f in glob.glob(dir + "\*.jpg")]
    list_images = sorted(list_images)
#     print("list image ",list_images[0])
    

    k = 10
    # loop over the images in each sub-folder
#     for x in range(1,images_per_class+1):
    for x in range(1,images_per_class+1):
        # get the image file name
#         file = dir + "\\" + current_label + "_" +str(x) + ".jpg"
        file = list_images[x]
#         print(file)
#         print(os.path.isfile(file))

        # read the image and resize it to a fixed-size
        image = cv2.imread(file)
#         image = cv2.
#         print(image.shape)
#         cv2.imshow("Test", image)
        image = cv2.resize(image, fixed_size)
#         print(image)

        ####################################
        # Global Feature extraction
        ####################################
        fv_hu_moments = fd_hu_moments(image)
        fv_haralick   = fd_haralick(image)
        fv_histogram  = fd_histogram(image)

        ###################################
        # Concatenate global features
        ###################################
        global_feature = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])

        # update the list of labels and feature vectors
        labels.append(current_label)
        global_features.append(global_feature)

        i += 1
        k += 1
    print ("[STATUS] processed folder: {}".format(current_label))
    j += 1

print ("[STATUS] completed Global Feature Extraction...")
# Out:
# Abyssinian
# [STATUS] processed folder: Abyssinian
# Bengal
# [STATUS] processed folder: Bengal
# Birman
# [STATUS] processed folder: Birman
# Bombay
# [STATUS] processed folder: Bombay
# British_Shorthair
# [STATUS] processed folder: British_Shorthair
# Maine_Coon
# [STATUS] processed folder: Maine_Coon
# Persian
# [STATUS] processed folder: Persian
# Ragdoll
# [STATUS] processed folder: Ragdoll
# Russian_Blue
# [STATUS] processed folder: Russian_Blue
# Siamese
# [STATUS] processed folder: Siamese
# Sphynx
# [STATUS] processed folder: Sphynx
# [STATUS] completed Global Feature Extraction...

# %%
# loop over the training data sub-folders
for training_name in train_labels:
    # join the training data path and each species training folder
    dir = os.path.join(train_path, training_name)

    # get the current training label
    current_label = training_name
    
    print(current_label)
    
    list_images = [f for f in glob.glob(dir + "\*.jpg")]
    list_images = sorted(list_images)
#     print("list image ",list_images[0])
    

    k = 10
    # loop over the images in each sub-folder
#     for x in range(1,images_per_class+1):
    for x in range(1,images_per_class+1):
        # get the image file name
#         file = dir + "\\" + current_label + "_" +str(x) + ".jpg"
        file = list_images[x]
        print(file)
        print(os.path.isfile(file))

        # read the image and resize it to a fixed-size
        image = cv2.imread(file)
#         image = cv2.cv
        print(image.shape)
#         cv2.imshow("Test", image)
        image = cv2.resize(image, fixed_size)
#         print(image)

        ####################################
        # Global Feature extraction
        ####################################
        fv_hu_moments = fd_hu_moments(image)
        fv_haralick   = fd_haralick(image)
        fv_histogram  = fd_histogram(image)

        ###################################
        # Concatenate global features
        ###################################
        global_feature = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])

        # update the list of labels and feature vectors
        labels.append(current_label)
        global_features.append(global_feature)

        i += 1
        k += 1
    print ("[STATUS] processed folder: {}".format(current_label))
    j += 1

print ("[STATUS] completed Global Feature Extraction...")
# Out:
# Abyssinian
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_10.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_100.jpg
# True
# (500, 394, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_101.jpg
# True
# (313, 450, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_102.jpg
# True
# (465, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_103.jpg
# True
# (351, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_104.jpg
# True
# (363, 600, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_105.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_106.jpg
# True
# (1024, 1536, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_107.jpg
# True
# (448, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_108.jpg
# True
# (404, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_109.jpg
# True
# (450, 282, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_11.jpg
# True
# (288, 192, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_110.jpg
# True
# (319, 400, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_111.jpg
# True
# (402, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_112.jpg
# True
# (500, 490, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_113.jpg
# True
# (425, 640, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_114.jpg
# True
# (423, 640, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_115.jpg
# True
# (367, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_116.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_117.jpg
# True
# (401, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_118.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_119.jpg
# True
# (297, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_12.jpg
# True
# (500, 335, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_120.jpg
# True
# (400, 267, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_121.jpg
# True
# (233, 242, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_122.jpg
# True
# (278, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_123.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_124.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_125.jpg
# True
# (359, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_126.jpg
# True
# (423, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_127.jpg
# True
# (400, 266, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_128.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_129.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_13.jpg
# True
# (280, 245, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_130.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_131.jpg
# True
# (320, 311, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_132.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_133.jpg
# True
# (496, 700, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_134.jpg
# True
# (440, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_135.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_136.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_137.jpg
# True
# (1200, 1600, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_138.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_139.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_14.jpg
# True
# (500, 335, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_140.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_141.jpg
# True
# (500, 461, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_142.jpg
# True
# (433, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_143.jpg
# True
# (461, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_144.jpg
# True
# (359, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_145.jpg
# True
# (577, 800, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_146.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_148.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_149.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian_15.jpg
# True
# (422, 477, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Abyssinian\Abyssinian
 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_2.jpg
# True
# (196, 275, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_20.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_21.jpg
# True
# (225, 225, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_215.jpg
# True
# (225, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_217.jpg
# True
# (293, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_22.jpg
# True
# (225, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_220.jpg
# True
# (225, 297, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_221.jpg
# True
# (316, 434, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Bombay\Bombay_23.jpg
# True
# (340, 500, 3)
# [STATUS] processed folder: Bombay
# British_Shorthair
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_100.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_101.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_102.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_103.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_104.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_105.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_106.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_107.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_108.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_109.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_110.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_111.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_112.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_113.jpg
# True
# (500, 457, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_114.jpg
# True
# (500, 328, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_115.jpg
# True
# (500, 423, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_116.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_117.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_118.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_119.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_120.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_121.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_122.jpg
# True
# (346, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_123.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_124.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_125.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_126.jpg
# True
# (500, 354, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_127.jpg
# True
# (500, 322, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_128.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_129.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_130.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_133.jpg
# True
# (335, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_134.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_135.jpg
# True
# (500, 465, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_136.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_137.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_139.jpg
# True
# (444, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_140.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_141.jpg
# True
# (500, 438, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_144.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_145.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_148.jpg
# True
# (281, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_149.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_15.jpg
# True
# (434, 600, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_151.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_153.jpg
# True
# (335, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_154.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_155.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_156.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_157.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_158.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_159.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_16.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\British_Shorthair\British_Shorthair_160.jpg
# True
# (333, 500, 3)
# ...
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_140.jpg
# True
# (500, 367, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_141.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_142.jpg
# True
# (439, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_143.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_144.jpg
# True
# (335, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_145.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_146.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_147.jpg
# True
# (374, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_148.jpg
# True
# (437, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_149.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_150.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_151.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_152.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_153.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_154.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_155.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_156.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_157.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_158.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_159.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_160.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_161.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_162.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_163.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_164.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_165.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_167.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_168.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_169.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_17.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_170.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_171.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_172.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_173.jpg
# True
# (500, 354, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_174.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_175.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_176.jpg
# True
# (400, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_178.jpg
# True
# (400, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_179.jpg
# True
# (439, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_18.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_180.jpg
# True
# (367, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_181.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_182.jpg
# True
# (350, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_183.jpg
# True
# (346, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_184.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_185.jpg
# True
# (500, 331, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_186.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Siamese\Siamese_19.jpg
# True
# (324, 432, 3)
# [STATUS] processed folder: Siamese
# Sphynx
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_102.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_103.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_104.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_105.jpg
# True
# (500, 481, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_107.jpg
# True
# (500, 334, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_108.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_11.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_110.jpg
# True
# (500, 376, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_111.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_112.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_114.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_115.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_116.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_117.jpg
# True
# (500, 334, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_119.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_12.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_121.jpg
# True
# (500, 334, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_122.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_124.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_125.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_126.jpg
# True
# (334, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_127.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_128.jpg
# True
# (281, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_129.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_130.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_131.jpg
# True
# (500, 334, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_132.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_133.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_134.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_136.jpg
# True
# (335, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_137.jpg
# True
# (312, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_138.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_139.jpg
# True
# (444, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_14.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_141.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_142.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_143.jpg
# True
# (366, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_144.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_145.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_146.jpg
# True
# (500, 380, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_148.jpg
# True
# (281, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_15.jpg
# True
# (349, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_150.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_151.jpg
# True
# (388, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_152.jpg
# True
# (480, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_153.jpg
# True
# (500, 332, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_155.jpg
# True
# (429, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_156.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_157.jpg
# True
# (354, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_158.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_159.jpg
# True
# (500, 364, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_160.jpg
# True
# (372, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_162.jpg
# True
# (351, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_164.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_165.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_166.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_167.jpg
# True
# (332, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_168.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_169.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_17.jpg
# True
# (500, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_170.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_171.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_172.jpg
# True
# (340, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_173.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_174.jpg
# True
# (401, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_175.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_176.jpg
# True
# (500, 330, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_177.jpg
# True
# (333, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_178.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_179.jpg
# True
# (500, 460, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_18.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_180.jpg
# True
# (500, 356, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_181.jpg
# True
# (327, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_182.jpg
# True
# (450, 300, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_183.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_184.jpg
# True
# (500, 358, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_185.jpg
# True
# (500, 375, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_186.jpg
# True
# (375, 500, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_187.jpg
# True
# (500, 333, 3)
# C:\Users\PERSONAL\AppData\Local\Programs\Python\Python36\Komandan_bocil\cat\train\Sphynx\Sphynx_188.jpg
# True
# (375, 500, 3)
# [STATUS] processed folder: Sphynx
# [STATUS] completed Global Feature Extraction...

# %%
# %%time
# get the overall feature vector size
print "[STATUS] feature vector size {}".format(np.array(global_features).shape)

# get the overall training label size
print "[STATUS] training Labels {}".format(np.array(labels).shape)

# encode the target labels
targetNames = np.unique(labels)
le = LabelEncoder()
target = le.fit_transform(labels)
print "[STATUS] training labels encoded..."

# normalize the feature vector in the range (0-1)
scaler = MinMaxScaler(feature_range=(0, 1))
rescaled_features = scaler.fit_transform(global_features)
print "[STATUS] feature vector normalized..."

print "[STATUS] target labels: {}".format(target)
print "[STATUS] target labels shape: {}".format(target.shape)

# save the feature vector using HDF5
h5f_data = h5py.File('output/data.h5', 'w')
h5f_data.create_dataset('dataset_1', data=np.array(rescaled_features))

h5f_label = h5py.File('output/labels.h5', 'w')
h5f_label.create_dataset('dataset_1', data=np.array(target))

h5f_data.close()
h5f_label.close()

print "[STATUS] end of training.."
# Out:
# Traceback (most recent call last):
#
#   File "c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py", line 3291, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-32-333c0bb25c23>", line 1, in <module>
#     get_ipython().run_cell_magic('time', '', '# get the overall feature vector size\nprint "[STATUS] feature vector size {}".format(np.array(global_features).shape)\n\n# get the overall training label size\nprint "[STATUS] training Labels {}".format(np.array(labels).shape)\n\n# encode the target labels\ntargetNames = np.unique(labels)\nle = LabelEncoder()\ntarget = le.fit_transform(labels)\nprint "[STATUS] training labels encoded..."\n\n# normalize the feature vector in the range (0-1)\nscaler = MinMaxScaler(feature_range=(0, 1))\nrescaled_features = scaler.fit_transform(global_features)\nprint "[STATUS] feature vector normalized..."\n\nprint "[STATUS] target labels: {}".format(target)\nprint "[STATUS] target labels shape: {}".format(target.shape)\n\n# save the feature vector using HDF5\nh5f_data = h5py.File(\'output/data.h5\', \'w\')\nh5f_data.create_dataset(\'dataset_1\', data=np.array(rescaled_features))\n\nh5f_label = h5py.File(\'output/labels.h5\', \'w\')\nh5f_label.create_dataset(\'dataset_1\', data=np.array(target))\n\nh5f_data.close()\nh5f_label.close()\n\nprint "[STATUS] end of training.."\n')
#
#   File "c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\IPython\core\interactiveshell.py", line 2347, in run_cell_magic
#     result = fn(magic_arg_s, cell)
#
#   File "<c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\decorator.py:decorator-gen-62>", line 2, in time
#
#   File "c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\IPython\core\magic.py", line 187, in <lambda>
#     call = lambda f, *a, **k: f(*a, **k)
#
#   File "c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\IPython\core\magics\execution.py", line 1256, in time
#     expr_ast = self.shell.compile.ast_parse(expr)
#
#   File "c:\users\personal\appdata\local\programs\python\python36\lib\site-packages\IPython\core\compilerop.py", line 100, in ast_parse
#     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
#   File "<unknown>", line 2
#     print "[STATUS] feature vector size {}".format(np.array(global_features).shape)
#                                           ^
# SyntaxError: invalid syntax

# %%
print ("===================")
print ("Training Classifier")
print ("===================")
import h5py
import numpy as np
import os
import glob2
import cv2
from matplotlib import pyplot
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.model_selection import KFold, StratifiedKFold
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.externals import joblib

# create all the machine learning models
models = []
models.append(('LR', LogisticRegression(random_state=9)))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier(random_state=9)))
models.append(('RF', RandomForestClassifier(n_estimators=num_trees, random_state=9)))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(random_state=9)))

# variables to hold the results and names
results = []
names = []
scoring = "accuracy"

# import the feature vector and trained labels
h5f_data = h5py.File('output/data.h5', 'r')
h5f_label = h5py.File('output/labels.h5', 'r')

global_features_string = h5f_data['dataset_1']
global_labels_string = h5f_label['dataset_1']

global_features = np.array(global_features_string)
global_labels = np.array(global_labels_string)

h5f_data.close()
h5f_label.close()

# verify the shape of the feature vector and labels
print "[STATUS] features shape: {}".format(global_features.shape)
print "[STATUS] labels shape: {}".format(global_labels.shape)

print "[STATUS] training started..."

# %%
# split the training and testing data
(trainDataGlobal, testDataGlobal, trainLabelsGlobal, testLabelsGlobal) = train_test_split(np.array(global_features),
                                                                                          np.array(global_labels),
                                                                                          test_size=test_size,
                                                                                          random_state=seed)

print "[STATUS] splitted train and test data..."
print "Train data  : {}".format(trainDataGlobal.shape)
print "Test data   : {}".format(testDataGlobal.shape)
print "Train labels: {}".format(trainLabelsGlobal.shape)
print "Test labels : {}".format(testLabelsGlobal.shape)

# %%
# %%time
# filter all the warnings
import warnings
warnings.filterwarnings('ignore')

# 10-fold cross validation
for name, model in models:
    kfold = KFold(n_splits=10, random_state=7)
    cv_results = cross_val_score(model, trainDataGlobal, trainLabelsGlobal, cv=kfold, scoring=scoring)
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)

# boxplot algorithm comparison
fig = pyplot.figure()
fig.suptitle('Machine Learning algorithm comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()

# %%
print ("======================================")
print ("Test Data Using Best Classifier Method")
print ("======================================")
import matplotlib.pyplot as plt
import glob

# create the model - Random Forests
clf  = RandomForestClassifier(n_estimators=100, random_state=9)

# fit the training data to the model
clf.fit(trainDataGlobal, trainLabelsGlobal)

# path to test data
test_path = "dataset/test"

# loop through the test images
for file in glob.glob(test_path + "/*.jpg"):
    # read the image
    image = cv2.imread(file)

    # resize the image
    image = cv2.resize(image, fixed_size)

    ####################################
    # Global Feature extraction
    ####################################
    fv_hu_moments = fd_hu_moments(image)
    fv_haralick   = fd_haralick(image)
    fv_histogram  = fd_histogram(image)

    ###################################
    # Concatenate global features
    ###################################
    global_feature = np.hstack([fv_histogram, fv_haralick, fv_hu_moments])

    # predict label of test image
    prediction = clf.predict(global_feature.reshape(1,-1))[0]

    # show predicted label on image
    cv2.putText(image, train_labels[prediction], (20,30), cv2.FONT_HERSHEY_SIMPLEX, 1.0, (0,255,255), 3)

    # display the output image
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.show()
